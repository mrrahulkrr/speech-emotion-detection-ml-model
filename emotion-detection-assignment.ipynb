# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

# import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# ## Import Modules

# %%
import pandas as pd
import numpy as np
import os
import seaborn as sns
import matplotlib.pyplot as plt
import librosa 
import librosa.display
from IPython.display import Audio
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Load the Dataset

# %%
paths = []
labels = []
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        paths.append(os.path.join(dirname, filename))
        label = filename.split('_')[-1]
        label = label.split('.')[0]
        labels.append(label.lower())
print('Dataset is loaded')
# Out:
# Dataset is loaded

# %%
paths[:6]
# Out:
# ['/kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_fear/YAF_home_fear.wav',
#  '/kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_fear/YAF_youth_fear.wav',
#  '/kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_fear/YAF_near_fear.wav',
#  '/kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_fear/YAF_search_fear.wav',
#  '/kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_fear/YAF_pick_fear.wav',
#  '/kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_fear/YAF_dodge_fear.wav']

# %%
labels[:10]
# Out:
# ['fear',
#  'fear',
#  'fear',
#  'fear',
#  'fear',
#  'fear',
#  'fear',
#  'fear',
#  'fear',
#  'fear']

# %%
# create a dataframe 
df = pd.DataFrame()
df['speech'] = paths
df['label'] = labels
df.head()
# Out:
#                                               speech label
# 0  /kaggle/input/toronto-emotional-speech-set-tes...  fear
# 1  /kaggle/input/toronto-emotional-speech-set-tes...  fear
# 2  /kaggle/input/toronto-emotional-speech-set-tes...  fear
# 3  /kaggle/input/toronto-emotional-speech-set-tes...  fear
# 4  /kaggle/input/toronto-emotional-speech-set-tes...  fear

# %%
df['label'].value_counts()
# Out:
# label
# fear       800
# angry      800
# disgust    800
# neutral    800
# sad        800
# ps         800
# happy      800
# Name: count, dtype: int64

# %% [markdown]
# ## Exploratory data analysis

# %%
def waveshow(data, sr, emotion):
    plt.figure(figsize=(11,4))
    plt.title(emotion, size=20)
    librosa.display.waveshow(data, sr=sr)
    plt.show()
    
def spectogram(data, sr, emotion):
    x = librosa.stft(data)
    xdb = librosa.amplitude_to_db(abs(x))
    plt.figure(figsize=(11,4))
    plt.title(emotion, size=20)
    librosa.display.specshow(xdb, sr=sr, x_axis='time', y_axis='hz',)
    plt.colorbar()

# %%
emotion = 'happy'
path = np.array(df['speech'][df['label']==emotion])[0]
data, sampling_rate = librosa.load(path)
waveshow(data, sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Displaying the plot
sns.countplot(data=df, x='label')

plt.show()

# %%
emotion = 'sad'
path = np.array(df['speech'][df['label']==emotion])[0]
data, sampling_rate = librosa.load(path)
waveshow(data, sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion = 'neutral'
path = np.array(df['speech'][df['label']==emotion])[0]
data, sampling_rate = librosa.load(path)
waveshow(data, sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## Feature Extraction

# %%
def extract_mfcc(filename):
    y, sr = librosa.load(filename, duration=3, offset=0.5)
    mfcc = np.mean(librosa.feature.mfcc(y=y, sr=sr, n_mfcc=40).T, axis=0)
    return mfcc

# %%
extract_mfcc(df['speech'][0])
# Out:
# array([-285.73727   ,   85.78295   ,   -2.1689112 ,   22.125532  ,
#         -14.757395  ,   11.051346  ,   12.412449  ,   -3.0002618 ,
#           1.0844991 ,   11.078272  ,  -17.41966   ,   -8.093213  ,
#           6.5879726 ,   -4.2209535 ,   -9.15508   ,    3.52148   ,
#         -13.186381  ,   14.078853  ,   19.66973   ,   22.725618  ,
#          32.57464   ,   16.325035  ,   -3.8427293 ,    0.89629656,
#         -11.239262  ,    6.653462  ,   -2.5883696 ,   -7.7140164 ,
#         -10.941658  ,   -2.4007547 ,   -5.281288  ,    4.271157  ,
#         -11.202216  ,   -9.024621  ,   -3.6669848 ,    4.869744  ,
#          -1.6027985 ,    2.5600514 ,   11.454374  ,   11.233449  ],
#       dtype=float32)

# %%
X_mfcc = df['speech'].apply(lambda x: extract_mfcc(x))

# %%
X_mfcc
# Out:
# 0       [-285.73727, 85.78295, -2.1689112, 22.125532, ...
# 1       [-348.34332, 35.193233, -3.841328, 14.658875, ...
# 2       [-340.11435, 53.796444, -14.267782, 20.884027,...
# 3       [-306.63422, 21.259708, -4.4110823, 6.4871554,...
# 4       [-344.7548, 46.329193, -24.171413, 19.392921, ...
#                               ...
# 5595    [-374.3952, 60.864998, 0.025059083, 8.431058, ...
# 5596    [-313.96478, 39.847843, -5.6493053, -3.867575,...
# 5597    [-357.54886, 77.886055, -15.224756, 2.194633, ...
# 5598    [-353.1474, 101.68391, -14.175896, -12.037376,...
# 5599    [-389.4595, 54.042767, 1.346998, -1.4258983, -...
# Name: speech, Length: 5600, dtype: object

# %%
X = [x for x in X_mfcc]
X = np.array(X)
X.shape
# Out:
# (5600, 40)

# %%
## input split
X = np.expand_dims(X, -1)
X.shape
# Out:
# (5600, 40, 1)

# %%
from sklearn.preprocessing import OneHotEncoder
enc = OneHotEncoder()
y = enc.fit_transform(df[['label']])

# %%
y = y.toarray()

# %%
y.shape
# Out:
# (5600, 7)

# %% [markdown]
# ## Create the LSTM Model

# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout

model = Sequential([
    LSTM(256, return_sequences=False, input_shape=(40,1)),
    Dropout(0.2),
    Dense(128, activation='relu'),
    Dropout(0.2),
    Dense(64, activation='relu'),
    Dropout(0.2),
    Dense(7, activation='softmax')
])

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 256)               264192
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense (Dense)               (None, 128)               32896
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 7)                 455
#
# =================================================================
# Total params: 305,799
# Trainable params: 305,799
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Train the model
history = model.fit(X, y, validation_split=0.2, epochs=50, batch_size=64)
# Out:
# Epoch 1/50
# 70/70 [==============================] - 11s 121ms/step - loss: 0.8113 - accuracy: 0.7094 - val_loss: 0.3914 - val_accuracy: 0.8607
# Epoch 2/50
# 70/70 [==============================] - 8s 114ms/step - loss: 0.2411 - accuracy: 0.9208 - val_loss: 0.1502 - val_accuracy: 0.9571
# Epoch 3/50
# 70/70 [==============================] - 8s 115ms/step - loss: 0.1643 - accuracy: 0.9502 - val_loss: 0.1034 - val_accuracy: 0.9705
# Epoch 4/50
# 70/70 [==============================] - 8s 120ms/step - loss: 0.1332 - accuracy: 0.9596 - val_loss: 0.1329 - val_accuracy: 0.9536
# Epoch 5/50
# 70/70 [==============================] - 8s 115ms/step - loss: 0.0947 - accuracy: 0.9719 - val_loss: 0.1246 - val_accuracy: 0.9616
# Epoch 6/50
# 70/70 [==============================] - 8s 116ms/step - loss: 0.0908 - accuracy: 0.9737 - val_loss: 0.0994 - val_accuracy: 0.9661
# Epoch 7/50
# 70/70 [==============================] - 8s 115ms/step - loss: 0.0747 - accuracy: 0.9766 - val_loss: 0.0921 - val_accuracy: 0.9696
# Epoch 8/50
# 70/70 [==============================] - 8s 118ms/step - loss: 0.0751 - accuracy: 0.9777 - val_loss: 0.1019 - val_accuracy: 0.9643
# Epoch 9/50
# 70/70 [==============================] - 8s 113ms/step - loss: 0.0837 - accuracy: 0.9717 - val_loss: 0.2001 - val_accuracy: 0.9348
# Epoch 10/50
# 70/70 [==============================] - 8s 115ms/step - loss: 0.0588 - accuracy: 0.9842 - val_loss: 0.0323 - val_accuracy: 0.9902
# Epoch 11/50
# 70/70 [==============================] - 8s 114ms/step - loss: 0.0609 - accuracy: 0.9799 - val_loss: 0.0405 - val_accuracy: 0.9893
# Epoch 12/50
# 70/70 [==============================] - 8s 118ms/step - loss: 0.0510 - accuracy: 0.9837 - val_loss: 0.0172 - val_accuracy: 0.9937
# Epoch 13/50
# 70/70 [==============================] - 8s 115ms/step - loss: 0.0487 - accuracy: 0.9862 - val_loss: 0.3440 - val_accuracy: 0.8920
# Epoch 14/50
# 70/70 [==============================] - 8s 114ms/step - loss: 0.0603 - accuracy: 0.9815 - val_loss: 0.0478 - val_accuracy: 0.9839
# Epoch 15/50
# 70/70 [==============================] - 8s 113ms/step - loss: 0.0370 - accuracy: 0.9891 - val_loss: 0.0159 - val_accuracy: 0.9946
# Epoch 16/50
# 70/70 [==============================] - 8s 117ms/step - loss: 0.0277 - accuracy: 0.9902 - val_loss: 0.0192 - val_accuracy: 0.9946
# Epoch 17/50
# 70/70 [==============================] - 8s 114ms/step - loss: 0.0307 - accuracy: 0.9908 - val_loss: 0.0236 - val_accuracy: 0.9929
# Epoch 18/50
# 70/70 [==============================] - 8s 114ms/step - loss: 0.0597 - accuracy: 0.9824 - val_loss: 0.0104 - val_accuracy: 0.9955
# Epoch 19/50
# 70/70 [==============================] - 8s 112ms/step - loss: 0.0214 - accuracy: 0.9929 - val_loss: 0.0259 - val_accuracy: 0.9902
# Epoch 20/50
# 70/70 [==============================] - 8s 115ms/step - loss: 0.0144 - accuracy: 0.9962 - val_loss: 0.0988 - val_accuracy: 0.9723
# Epoch 21/50
# 70/70 [==============================] - 8s 113ms/step - loss: 0.0360 - accuracy: 0.9911 - val_loss: 0.0709 - val_accuracy: 0.9732
# Epoch 22/50
# 70/70 [==============================] - 8s 113ms/step - loss: 0.0180 - accuracy: 0.9946 - val_loss: 0.0086 - val_accuracy: 0.9973
# Epoch 23/50
# 70/70 [==============================] - 8s 113ms/step - loss: 0.0137 - accuracy: 0.9964 - val_loss: 0.0247 - val_accuracy: 0.9920
# Epoch 24/50
# 70/70 [==============================] - 8s 115ms/step - loss: 0.0429 - accuracy: 0.9886 - val_loss: 0.0858 - val_accuracy: 0.9732
# Epoch 25/50
# 70/70 [==============================] - 8s 112ms/step - loss: 0.0278 - accuracy: 0.9913 - val_loss: 0.0102 - val_accuracy: 0.9964
# Epoch 26/50
# 70/70 [==============================] - 8s 112ms/step - loss: 0.0438 - accuracy: 0.9868 - val_loss: 0.0163 - val_accuracy: 0.9955
# Epoch 27/50
# 70/70 [==============================] - 8s 113ms/step - loss: 0.0317 - accuracy: 0.9902 - val_loss: 0.0317 - val_accuracy: 0.9911
# Epoch 28/50
# 70/70 [==============================] - 8s 115ms/step - loss: 0.0238 - accuracy: 0.9924 - val_loss: 0.0675 - val_accuracy: 0.9786
# Epoch 29/50
# 70/70 [==============================] - 8s 112ms/step - loss: 0.0217 - accuracy: 0.9933 - val_loss: 0.0236 - val_accuracy: 0.9929
# Epoch 30/50
# 70/70 [==============================] - 8s 113ms/step - loss: 0.0269 - accuracy: 0.9926 - val_loss: 0.0088 - val_accuracy: 0.9973
# Epoch 31/50
# 70/70 [==============================] - 8s 112ms/step - loss: 0.0102 - accuracy: 0.9971 - val_loss: 0.0057 - val_accuracy: 0.9973
# Epoch 32/50
# 70/70 [==============================] - 8s 117ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0051 - val_accuracy: 0.9973
# Epoch 33/50
# 70/70 [==============================] - 8s 112ms/step - loss: 0.0107 - accuracy: 0.9969 - val_loss: 0.0028 - val_accuracy: 0.9991
# Epoch 34/50
# 70/70 [==============================] - 8s 113ms/step - loss: 0.0054 - accuracy: 0.9980 - val_loss: 0.0059 - val_accuracy: 0.9982
# Epoch 35/50
# 70/70 [==============================] - 8s 113ms/step - loss: 0.0114 - accuracy: 0.9962 - val_loss: 0.0450 - val_accuracy: 0.9839
# Epoch 36/50
# 70/70 [==============================] - 8s 116ms/step - loss: 0.0261 - accuracy: 0.9937 - val_loss: 0.0329 - val_accuracy: 0.9884
# Epoch 37/50
# 70/70 [==============================] - 8s 112ms/step - loss: 0.0103 - accuracy: 0.9975 - val_loss: 0.0116 - val_accuracy: 0.9946
# Epoch 38/50
# 70/70 [==============================] - 8s 113ms/step - loss: 0.0096 - accuracy: 0.9973 - val_loss: 0.0141 - val_accuracy: 0.9937
# Epoch 39/50
# 70/70 [==============================] - 8s 111ms/step - loss: 0.0137 - accuracy: 0.9958 - val_loss: 0.0113 - val_accuracy: 0.9946
# Epoch 40/50
# 70/70 [==============================] - 8s 115ms/step - loss: 0.0023 - accuracy: 0.9996 - val_loss: 0.0012 - val_accuracy: 0.9991
# Epoch 41/50
# 70/70 [==============================] - 8s 113ms/step - loss: 0.0013 - accuracy: 0.9998 - val_loss: 6.5832e-04 - val_accuracy: 1.0000
# Epoch 42/50
# 70/70 [==============================] - 8s 114ms/step - loss: 4.5361e-04 - accuracy: 1.0000 - val_loss: 4.8681e-04 - val_accuracy: 1.0000
# Epoch 43/50
# 70/70 [==============================] - 8s 113ms/step - loss: 3.8842e-04 - accuracy: 1.0000 - val_loss: 3.5760e-04 - val_accuracy: 1.0000
# Epoch 44/50
# 70/70 [==============================] - 8s 116ms/step - loss: 5.8554e-04 - accuracy: 0.9998 - val_loss: 3.0342e-04 - val_accuracy: 1.0000
# Epoch 45/50
# 70/70 [==============================] - 8s 112ms/step - loss: 5.4013e-04 - accuracy: 0.9998 - val_loss: 1.5139e-04 - val_accuracy: 1.0000
# Epoch 46/50
# 70/70 [==============================] - 8s 113ms/step - loss: 2.1877e-04 - accuracy: 1.0000 - val_loss: 1.2019e-04 - val_accuracy: 1.0000
# Epoch 47/50
# 70/70 [==============================] - 8s 112ms/step - loss: 2.1620e-04 - accuracy: 1.0000 - val_loss: 1.1058e-04 - val_accuracy: 1.0000
# Epoch 48/50
# 70/70 [==============================] - 8s 115ms/step - loss: 1.5180e-04 - accuracy: 1.0000 - val_loss: 1.0211e-04 - val_accuracy: 1.0000
# Epoch 49/50
# 70/70 [==============================] - 8s 112ms/step - loss: 1.0148e-04 - accuracy: 1.0000 - val_loss: 9.9150e-05 - val_accuracy: 1.0000
# Epoch 50/50
# 70/70 [==============================] - 8s 112ms/step - loss: 1.2459e-04 - accuracy: 1.0000 - val_loss: 8.7083e-05 - val_accuracy: 1.0000

# %% [markdown]
# ## Ploting the Results

# %%
epochs = list(range(50))
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

plt.plot(epochs, acc, label='train accuracy')
plt.plot(epochs, val_acc, label='val accuracy')
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.legend()
plt.show()

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']

plt.plot(epochs, loss, label='train loss')
plt.plot(epochs, val_loss, label='val loss')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()
